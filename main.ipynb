# %% [markdown]
# # Load Data

# %%
from utils import *

data_dir = "physionet.org/files/nsr2db/1.0.0"
rr_data = load_rr_intervals(data_dir)
# Out:
#   nsr001: 106464 beats, mean HR = 79.0 bpm
#   nsr002: 111334 beats, mean HR = 79.5 bpm
#   nsr003: 97585 beats, mean HR = 69.3 bpm
#   nsr004: 97821 beats, mean HR = 70.5 bpm
#   nsr005: 116773 beats, mean HR = 81.7 bpm
#   nsr006: 102662 beats, mean HR = 74.3 bpm
#   nsr007: 106792 beats, mean HR = 76.1 bpm
#   nsr008: 107739 beats, mean HR = 75.4 bpm
#   nsr009: 102861 beats, mean HR = 71.8 bpm
#   nsr010: 96252 beats, mean HR = 70.1 bpm
#   nsr011: 115900 beats, mean HR = 81.5 bpm
#   nsr012: 98905 beats, mean HR = 69.1 bpm
#   nsr013: 115757 beats, mean HR = 82.3 bpm
#   nsr014: 111896 beats, mean HR = 78.2 bpm
#   nsr015: 100961 beats, mean HR = 75.9 bpm
#   nsr016: 94767 beats, mean HR = 77.2 bpm
#   nsr017: 100959 beats, mean HR = 70.4 bpm
#   nsr018: 107982 beats, mean HR = 77.3 bpm
#   nsr019: 122822 beats, mean HR = 85.7 bpm
#   nsr020: 136481 beats, mean HR = 97.7 bpm
#   nsr021: 103875 beats, mean HR = 72.5 bpm
#   nsr022: 81720 beats, mean HR = 57.8 bpm
#   nsr023: 112094 beats, mean HR = 78.2 bpm
#   nsr024: 101102 beats, mean HR = 70.9 bpm
#   nsr025: 128789 beats, mean HR = 91.3 bpm
#   nsr026: 116482 beats, mean HR = 81.4 bpm
#   nsr027: 112713 beats, mean HR = 81.1 bpm
#   nsr028: 108037 beats, mean HR = 76.4 bpm
#   nsr029: 116387 beats, mean HR = 87.3 bpm
#   nsr030: 104874 beats, mean HR = 74.9 bpm
#   nsr031: 110280 beats, mean HR = 81.7 bpm
#   nsr032: 102501 beats, mean HR = 74.1 bpm
#   nsr033: 76760 beats, mean HR = 58.2 bpm
#   nsr034: 97708 beats, mean HR = 71.1 bpm
#   nsr035: 117821 beats, mean HR = 83.4 bpm
#   nsr036: 113845 beats, mean HR = 82.7 bpm
#   nsr037: 93449 beats, mean HR = 68.5 bpm
#   nsr038: 101864 beats, mean HR = 82.0 bpm
#   nsr039: 98927 beats, mean HR = 72.1 bpm
#   nsr040: 117681 beats, mean HR = 83.3 bpm
#   nsr041: 102032 beats, mean HR = 79.3 bpm
#   nsr042: 108084 beats, mean HR = 75.6 bpm
#   nsr043: 103046 beats, mean HR = 78.3 bpm
#   nsr044: 111115 beats, mean HR = 81.9 bpm
#   nsr045: 94122 beats, mean HR = 73.1 bpm
#   nsr046: 95312 beats, mean HR = 69.8 bpm
#   nsr047: 112932 beats, mean HR = 78.5 bpm
#   nsr048: 116264 beats, mean HR = 83.0 bpm
#   nsr049: 104044 beats, mean HR = 73.6 bpm
#   nsr050: 127043 beats, mean HR = 88.5 bpm
#   nsr051: 106652 beats, mean HR = 74.5 bpm
#   nsr052: 118805 beats, mean HR = 87.1 bpm
#   nsr053: 98731 beats, mean HR = 73.1 bpm
#   nsr054: 119848 beats, mean HR = 87.1 bpm
#
# Loaded 54 records, 5,787,652 total beats

# %% [markdown]
# # Step 1: build the cumulative time series B(i) from the detrended and normalised heart beat time series b(i)
